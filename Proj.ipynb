# %%
import pandas as pd

import re

from sklearn.pipeline import Pipeline
from sklearn.naive_bayes import MultinomialNB
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import classification_report

# %%
reviews_json_file  = 'dataset/goodreads_reviews_poetry.json'
reviews_json = pd.read_json(reviews_json_file, convert_dates = True, lines = True)

reviews_json.head()
# Out:
#    book_id                      date_added                    date_updated  \
# 0   402128  Tue Jun 12 08:59:04 -0700 2012  Fri Jun 15 11:41:12 -0700 2012
# 1    92270  Mon Apr 14 18:42:40 -0700 2014  Mon Apr 14 18:43:05 -0700 2014
# 2   908708  Tue Apr 22 13:58:10 -0700 2008  Tue Apr 22 13:58:33 -0700 2008
# 3   253264  Wed Sep 27 19:08:08 -0700 2017  Sat Sep 30 06:39:45 -0700 2017
# 4    70885  Thu Jun 18 20:00:03 -0700 2015  Thu Jun 18 20:01:29 -0700 2015
#
#    n_comments  n_votes  rating                         read_at  \
# 0           0        0       5
# 1           0        0       5  Wed Jan 01 00:00:00 -0800 1997
# 2           0        0       4
# 3           0        1       5  Wed Sep 27 00:00:00 -0700 2017
# 4           0        0       5  Thu Jun 18 00:00:00 -0700 2015
#
#                           review_id  \
# 0  28423ff309bc896c071a8d9df4a10e8a
# 1  2db1180992e2b0b1631a3ac5644bde84
# 2  bca57fa40e92c9261b00b03dbebd96fe
# 3  cb1ebc02d8b2aff15735d513877463ce
# 4  8dca128b8e869048a7442c18659dbece
#
#                                          review_text  \
# 0  I have three younger siblings and we grew up w...
# 1          This is my favorite collection of poetry.
# 2      He's so disturbing. So very, very disturbing.
# 3  I just reread this play for a class I am takin...
# 4  Cuanto mas leo, mas me gusta. Su poesia es env...
#
#                        started_at                           user_id
# 0                                  3ca7375dba942a760e53b726c472a7dd
# 1                                  0ef32090550901ead25cb0ea21c4d36b
# 2                                  0ef32090550901ead25cb0ea21c4d36b
# 3  Tue Sep 26 00:00:00 -0700 2017  d37b46b2190ed7c518259f29b47a9b36
# 4  Tue Jun 16 00:00:00 -0700 2015  af157d0205b8a901dee6d4a2aed7e6ad

# %%
reviews = reviews_json['review_text']
reviews
# Out:
# 0         I have three younger siblings and we grew up w...
# 1                 This is my favorite collection of poetry.
# 2             He's so disturbing. So very, very disturbing.
# 3         I just reread this play for a class I am takin...
# 4         Cuanto mas leo, mas me gusta. Su poesia es env...
# 5         Adorablemente pesimista, deprimente y repulsiv...
# 6         Poemas crudos y reales, sin tanto adorno aun u...
# 7         This ain't a book with to die for characters, ...
# 8                      This is why kids don't like to read.
# 9         Odysseus is such an arrogant, power-hungry man...
# 10        Toinen tekija on Olavi Lauri = Paavolainen. Lu...
# 11                          sTHy wmml w 'Glb lmfrdt tkrrt .
# 12        k`d@ frwq jwyd@ y'sr lqr bqSy'dh l`dhb@ lmlyy'...
# 13        jmyl jd [?][?] \n " lmdh 'rki `l~ klW shy bqy ...
# 14        ry'` sh`ran ... mml nthran \n mjl@ wmlHq ldwH@...
# 15        Beyond the Words is an anthology of poetry and...
# 16        Thoughts of a Pure Mind by Calvin Bland is a c...
# 17        Seeing Past Sickness is a collection of 17 pie...
# 18        Interesting break from what I've been reading ...
# 19        Simply breathtaking! A MUST READ! \n Life Unde...
# 20        Long and a bit boring in places. \n Longer rev...
# 21        Aiheeltaan ihan mielenkiintoinen tenttikirja, ...
# 22        teatteriluentoja varten luettu naytelma. Ensin...
# 23        Hyva naytelma, Minna Canthin tekstit ovat aina...
# 24        Jalleen kerran enemman ja vahemman outoja runo...
# 25        Runoutta pitaisi ymmartaa, varsinkin kun alaa ...
# 26        Paras runo on Tunteellinen siili, ehdottomasti...
# 27        Erittain hihityttavaa luettavaa :). Taas tuli ...
# 28                                 A quick and amusing read
# 29        This was a wonderful book of poems, written by...
#                                 ...
# 154525    Este libro es una delicia, por mas gallo que p...
# 154526                            this is my awesome review
# 154527                                       inspirational!
# 154528    bqy@ Hy@ \n dh qyl ly: stmwtu hn fy lms \n fmd...
# 154529    jmyl jd lktb ydly,bsm llh m sh llh,mn 'jml lmq...
# 154530                                       Very Enjoyable
# 154531    I am writing this review while the images from...
# 154532    Poignant and heartfelt, Lang Leave knows how t...
# 154533    ktb jmyl w mkhtlf 'yDan llktb fhd l`wd@ , lGth...
# 154534                                  ktb 'ql mn `dy jdan
# 154535    I would definitely recommend this collection t...
# 154536    Romantic, sad, melancholy collection of tanka....
# 154537    This is like my 2nd soulmate beside coffee. I ...
# 154538    "His name is Boredom. He sniffs, wipes his eye...
# 154539    rng aby \n dwst drm hmh j nm tw r \n Grq zybyy...
# 154540    Robert Fagles translation of The Aeneid, like ...
# 154541    Irish lit in college...has remained a reread, ...
# 154542    At times difficult to hold interest, but amazi...
# 154543    What a difference decades make. I read this in...
# 154544    This is a great book. Check out his talks on Y...
# 154545    z chshm tw kh dr bnd~ drwysh \n jhn~ zndn~ st ...
# 154546    "`mqi akhryn Hrf h \n mthli ystdn knri drh ~ \...
# 154547    I've started reading this a few times and have...
# 154548                                              ry'` :)
# 154549                                      <3 I LOVE IT!!!
# 154550    When Eve finds Adam, he drops the wreath and i...
# 154551    sh`rhyy khml `shqnh w Hsy z dydgh ykh mrd. bry...
# 154552    nZr ahry nwysndh y st khh dr Hwzh dbyt dstny m...
# 154553    Emily Dickinson left a large cache of poetry -...
# 154554    My Emily Dickinson is a deliciously dense conc...
# Name: review_text, Length: 154555, dtype: object

# %%
reviews = reviews.to_frame()

# %%
type(reviews)
# Out:
# pandas.core.frame.DataFrame

# %%
reviews['pos_neg'] = [1 if x>3 else 0 for x in reviews_json.rating]

# %%
reviews
# Out:
#                                               review_text  pos_neg
# 0       I have three younger siblings and we grew up w...        1
# 1               This is my favorite collection of poetry.        1
# 2           He's so disturbing. So very, very disturbing.        1
# 3       I just reread this play for a class I am takin...        1
# 4       Cuanto mas leo, mas me gusta. Su poesia es env...        1
# 5       Adorablemente pesimista, deprimente y repulsiv...        1
# 6       Poemas crudos y reales, sin tanto adorno aun u...        1
# 7       This ain't a book with to die for characters, ...        1
# 8                    This is why kids don't like to read.        0
# 9       Odysseus is such an arrogant, power-hungry man...        0
# 10      Toinen tekija on Olavi Lauri = Paavolainen. Lu...        1
# 11                        sTHy wmml w 'Glb lmfrdt tkrrt .        0
# 12      k`d@ frwq jwyd@ y'sr lqr bqSy'dh l`dhb@ lmlyy'...        1
# 13      jmyl jd [?][?] \n " lmdh 'rki `l~ klW shy bqy ...        1
# 14      ry'` sh`ran ... mml nthran \n mjl@ wmlHq ldwH@...        0
# 15      Beyond the Words is an anthology of poetry and...        1
# 16      Thoughts of a Pure Mind by Calvin Bland is a c...        0
# 17      Seeing Past Sickness is a collection of 17 pie...        1
# 18      Interesting break from what I've been reading ...        0
# 19      Simply breathtaking! A MUST READ! \n Life Unde...        1
# 20      Long and a bit boring in places. \n Longer rev...        0
# 21      Aiheeltaan ihan mielenkiintoinen tenttikirja, ...        0
# 22      teatteriluentoja varten luettu naytelma. Ensin...        1
# 23      Hyva naytelma, Minna Canthin tekstit ovat aina...        1
# 24      Jalleen kerran enemman ja vahemman outoja runo...        0
# 25      Runoutta pitaisi ymmartaa, varsinkin kun alaa ...        0
# 26      Paras runo on Tunteellinen siili, ehdottomasti...        0
# 27      Erittain hihityttavaa luettavaa :). Taas tuli ...        1
# 28                               A quick and amusing read        1
# 29      This was a wonderful book of poems, written by...        1
# ...                                                   ...      ...
# 154525  Este libro es una delicia, por mas gallo que p...        1
# 154526                          this is my awesome review        1
# 154527                                     inspirational!        1
# 154528  bqy@ Hy@ \n dh qyl ly: stmwtu hn fy lms \n fmd...        0
# 154529  jmyl jd lktb ydly,bsm llh m sh llh,mn 'jml lmq...        1
# 154530                                     Very Enjoyable        1
# 154531  I am writing this review while the images from...        1
# 154532  Poignant and heartfelt, Lang Leave knows how t...        1
# 154533  ktb jmyl w mkhtlf 'yDan llktb fhd l`wd@ , lGth...        1
# 154534                                ktb 'ql mn `dy jdan        0
# 154535  I would definitely recommend this collection t...        1
# 154536  Romantic, sad, melancholy collection of tanka....        0
# 154537  This is like my 2nd soulmate beside coffee. I ...        0
# 154538  "His name is Boredom. He sniffs, wipes his eye...        1
# 154539  rng aby \n dwst drm hmh j nm tw r \n Grq zybyy...        0
# 154540  Robert Fagles translation of The Aeneid, like ...        1
# 154541  Irish lit in college...has remained a reread, ...        1
# 154542  At times difficult to hold interest, but amazi...        1
# 154543  What a difference decades make. I read this in...        1
# 154544  This is a great book. Check out his talks on Y...        1
# 154545  z chshm tw kh dr bnd~ drwysh \n jhn~ zndn~ st ...        1
# 154546  "`mqi akhryn Hrf h \n mthli ystdn knri drh ~ \...        1
# 154547  I've started reading this a few times and have...        0
# 154548                                            ry'` :)        1
# 154549                                    <3 I LOVE IT!!!        1
# 154550  When Eve finds Adam, he drops the wreath and i...        1
# 154551  sh`rhyy khml `shqnh w Hsy z dydgh ykh mrd. bry...        0
# 154552  nZr ahry nwysndh y st khh dr Hwzh dbyt dstny m...        0
# 154553  Emily Dickinson left a large cache of poetry -...        1
# 154554  My Emily Dickinson is a deliciously dense conc...        1
#
# [154555 rows x 2 columns]

# %%
def preprocess_text(text):
    text = re.sub('((www\.[^\s]+)|(https?://[^\s]+))','URL', text)
    text = re.sub('@[^\s]+','USER', text)
    text = text.lower().replace("ё", "е")
    text = re.sub('[^a-zA-Zа-яА-Я1-9]+', ' ', text)
    text = re.sub(' +',' ', text)
    return text.strip()

reviews['review_text'] = [preprocess_text(t) for t in reviews['review_text']]

# %%
text_clf = Pipeline([('vect', CountVectorizer()), ('tfidf', TfidfTransformer()), ('clf', MultinomialNB())])

tuned_parameters = {
    'vect__ngram_range' : [(1,1), (1,2), (2,2)],
    'tfidf__use_idf' : (True, False),
    'tfidf__norm' : ('l1', 'l2'),
    'clf__alpha' : [1, 1e-1, 1e-2]
}

# %%
x_train, x_test, y_train, y_test = train_test_split(reviews['review_text'],reviews['pos_neg'], test_size = 0.2, random_state = 42)
x_train
# Out:
# 85137     i read the first two books in the september se...
# 33589     i couldn t put this book down i m a huge fan o...
# 81053     i love this book so much every poem i m saving...
# 103909                                          so much fun
# 33586     i watched the movie months ago but only last n...
# 80346     wow what a journey from the beggining to the l...
# 130810    you haven t read don mckay yet and you call yo...
# 47537     gilgamesheposet ar ett oerhort intressant verk...
# 9720      rqyq hlm wtkhrj m f lnfs bklmth lt ttwjd dkhl ...
# 53081     finished at my parents house eating birthday cake
# 102956    i ve been reading a bunch of lauren springer l...
# 69569     abbas kiarostami is one of my favouritest film...
# 138818    when you find yourself highlighting the majori...
# 81877     3 5 stars very densely packed metaphors and lo...
# 44170     really really wanted to like this one but some...
# 54247     lsrwu fy m stn srkhn dkhmu mn swtn wsyfun twlu...
# 77687     this is so uncreative and boring i couldn t ev...
# 71912     ktb ry hl mn lt ml t khdhk l lm khr lwl trd l ...
# 129907    qd tsm twsy lktb lky thrs l qr th hn fqt lw sm...
# 60442                                    excelentes poesias
# 58485     lo que ocurre aqui es que no puedo darle mas e...
# 67545                                   wonderful creations
# 7291      i have almost no middle english but i can read...
# 126988    just wanted to let you guys know i read the en...
# 113809                          men doing manly things bros
# 17892     benjamin crouched beneath the rotting metal he...
# 108376    another timely read as we ve read listened to ...
# 15822                          what a beautiful little book
# 138448                          qtlwh lbd klmt rhm llh lhlj
# 137262    bsyr shgft zdh shdm z khwndn khtby khh byshtr ...
#                                 ...
# 129981    i heard renee read from this collection earlie...
# 65725     mgr my shwd nymdh bz bh jnbi an hmh by nshnyi ...
# 123855    this collection of poetry will put you smack i...
# 2747      km jz fy lktb jbwny lkn mn tryq lktb hsh n lkt...
# 130523               book reviews ummburpoops wordpress com
# 149503    bence kitap reklamdan dolayi bu kadar tutuldu ...
# 122537    this is a marvelous collection presented beaut...
# 84478     this was for the book discussin group i had to...
# 130608                                   ktb mmt wmly blhkm
# 85305     i m just going to throw all of my stars and al...
# 103355    i heard about rupi kaur when she posted the pe...
# 5311      why am i reading old white men poets because t...
# 64925     shakespeare is so awesome layers upon layers u...
# 59735     i can imagine this being a cult favourite sola...
# 769       i ve read three translations of the odyssey an...
# 64820     the rating is purely for the content not the p...
# 67221     poet dean baker has no qualms about diving int...
# 41090     1 this is a very fun very clever and generally...
# 16023     this is the second book of keene s i read this...
# 126324    one of our discussion group suggested we bring...
# 112727                                       review to come
# 87498     qryth ktr mn shr mrt bhbh wy wnsh y hd yshtryh...
# 137337    wdy s d byfshkh llguser wbyfshkh ldhhn byfshkh...
# 54886     i don t normally read books of poetry but i li...
# 110268      words can t describe how i am feeling right now
# 119879    it s for good reason that this is considered o...
# 103694                   some excellent poetry in this book
# 131932    the best damn explanation of surrealism i ve e...
# 146867    would fly to attend a workshop with this gifte...
# 121958    definitely a helpful reference for beginning p...
# Name: review_text, Length: 123644, dtype: object

# %%
clf = GridSearchCV(text_clf, tuned_parameters, cv=10)
clf.fit(x_train, y_train)
# Out:
# GridSearchCV(cv=10, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('vect',
#                                         CountVectorizer(analyzer='word',
#                                                         binary=False,
#                                                         decode_error='strict',
#                                                         dtype=<class 'numpy.int64'>,
#                                                         encoding='utf-8',
#                                                         input='content',
#                                                         lowercase=True,
#                                                         max_df=1.0,
#                                                         max_features=None,
#                                                         min_df=1,
#                                                         ngram_range=(1, 1),
#                                                         preprocessor=None,
#                                                         stop_words=None,
#                                                         strip_accents=None,
#                                                         to...
#                                                          sublinear_tf=False,
#                                                          use_idf=True)),
#                                        ('clf',
#                                         MultinomialNB(alpha=1.0,
#                                                       class_prior=None,
#                                                       fit_prior=True))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'clf__alpha': [1, 0.1, 0.01],
#                          'tfidf__norm': ('l1', 'l2'),
#                          'tfidf__use_idf': (True, False),
#                          'vect__ngram_range': [(1, 1), (1, 2), (2, 2)]},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring=None, verbose=0)
